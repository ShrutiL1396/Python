# %%
#pip install powerbiclient

# %%
from powerbiclient import Report, models
from IPython.display import Image, display

# %%
# Import the DeviceCodeLoginAuthentication class to authenticate against Power BI
from powerbiclient.authentication import DeviceCodeLoginAuthentication

# Initiate device authentication
device_auth = DeviceCodeLoginAuthentication()
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
#  To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code RT8ZP684T to authenticate.
# You have logged in.
# Interactive authentication successfully completed.

# %%
group_id="02f8f32e-01f2-41fd-b450-cf51f18a2dbd"
report_id="aa0fc782-be55-441d-b867-da1336fb8a09"

# %%
report = Report(group_id=group_id, report_id=report_id, auth=device_auth)
report
# Out:
# Report()

# %%
display(Image(filename='C:/Users/lanke/OneDrive/Desktop/Power BI Content/Report 1.png', embed=True))

# %%
display(Image(filename='C:/Users/lanke/OneDrive/Desktop/Power BI Content/Report 2.png', embed=True))
